# %% [markdown]
# <a href="https://colab.research.google.com/github/NiteshIITJ23/colab_test_repo/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate Data
x = np.linspace(0, 10, 100)
y = np.sin(x)

print('hi this is for github tutorial')

# Plot
plt.figure(figsize=(6,4))
plt.plot(x, y, label="Sine Wave")
plt.legend()
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sine Wave Graph")
plt.show()
# Out:
# hi this is for github tutorial

# %%
import matplotlib.pyplot as plt

# Create a figure and axis
fig, ax = plt.subplots()

# Add a circle to the plot
circle = plt.Circle((0.5, 0.5), 0.4, color='blue', fill=True)

# Add the circle to the axes
ax.add_artist(circle)

# Set the aspect of the plot to be equal
ax.set_aspect('equal')

# Set the limits of the plot
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)

# Display the plot
plt.show()
